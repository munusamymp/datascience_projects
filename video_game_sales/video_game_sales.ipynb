# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1) Source of data
#
# https://www.kaggle.com/gregorut/videogamesales?select=vgsales.csv
#
# 2) Brief description of data
#
# This dataset contains a list of video games with sales greater than 100,000 copies. It was generated by a scrape of vgchartz.com.
#
#
# 3) What is the target?
#
# To predict the Global_Sales
#
# 4) Is this a classification or regression problem?
#
# Regression Problem
#
# 5) How many features?
#
# 11 Features
#
# 6) How many rows of data.
#
# 16598
#
# 7) What, if any, challenges do your foresee in cleaning, exploring, or modeling with this dataset?
#
# Year(271) missing values and will be filling data with bfill or zero.
#
# Publisher(58) missing values and will be filling with bfill.

# %%
filepath = '/content/drive/MyDrive/1CodingDojo/Week7_2/vgsales.csv'

df = pd.read_csv(filepath)
df.head()
# Out:
#    Rank                      Name Platform  ...  JP_Sales Other_Sales Global_Sales
# 0     1                Wii Sports      Wii  ...      3.77        8.46        82.74
# 1     2         Super Mario Bros.      NES  ...      6.81        0.77        40.24
# 2     3            Mario Kart Wii      Wii  ...      3.79        3.31        35.82
# 3     4         Wii Sports Resort      Wii  ...      3.28        2.96        33.00
# 4     5  Pokemon Red/Pokemon Blue       GB  ...     10.22        1.00        31.37
#
# [5 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64
